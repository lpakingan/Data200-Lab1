# %%
import csv
import getpass
import shutil
import unittest
import random
import time

class LoginUser:
    '''user class that includes a user's login information for the application'''
    def __init__(self, email_address, password):
        self.email_address = email_address
        self.password = password

    def get_logins(self):
        login_data = LinkedList()
        with open('login.csv', newline = '') as csvfile:
            logins = csv.reader(csvfile)
            next(logins)
            for login in logins:
                login_data.add_new(login)
            return login_data

    def login(self):
        '''checks the login details of the current user and logs them in if correct'''
        # linked list method
        logins = self.get_logins()
        login_exists = False
        if logins.check_head():
            c1 = logins.head
            while c1 is not None:
                if c1.data[0] == self.email_address:
                    encrypted_password = self.encrypt_password(self.password)
                    if encrypted_password == c1.data[1]:
                        print('You are now logged in!')
                        print(f'{c1.data[0]}: {c1.data[1]}')
                        login_exists = True
                        return True, c1.data[0], c1.data[2]
                    else:
                        print("Unable to login! Returning to login screen...")
                        login_exists = True
                        return False, None, None
                else: 
                    print('Checking next...')
                    c1 = c1.next

        if not login_exists:
            print('The email address is not associated with an account!')
            return False, None, None

    def logout(self):
        '''logs the current user out of the system'''
        return False

    def change_password(self):
        '''changes a user's password'''
        logins_ll, login_list, header = get_data('login.csv')
        for login in login_list:
            if login[0] == self.email_address:
                new_password = getpass.getpass("Enter your new password: ")
                encrypted_new_password = self.encrypt_password(new_password)
                login[1] = self.password = encrypted_new_password
        write_to_file_array('login.csv', header, login_list)
        print(f'Your password has been updated! Please try logging in with your new password...')
        return False

    def encrypt_password(self, password):
        '''encrypts a user's password'''
        preencrypted_password = PasswordEncryptor(4)
        encrypted_password = preencrypted_password.encrypt(password)
        return encrypted_password

    def decrypt_password(self, password):
        '''decrypts a user's password'''
        predecrypted_password = PasswordEncryptor(4)
        decrypted_password = predecrypted_password.decrypt(password)
        return decrypted_password

class PasswordEncryptor:
    '''encrypts and decrypts password'''
    def __init__(self, shift):
        self.shifter=shift
        self.s=self.shifter%26
  
    def _convert(self, text,s):
        '''encrypts/decrypts the password'''
        result=""
        for i,ch in enumerate(text):     
             if (ch.isupper()):
                  result += chr((ord(ch) + s-65) % 26 + 65)
             else:
                  result += chr((ord(ch) + s-97) % 26 + 97)
        return  result
  
    def encrypt(self, text):
        '''encrypts the password'''
        return self._convert(text,self.shifter)
        
    def decrypt(self, text):
        '''decrypts the password'''
        return self._convert(text,26-self.s) 

class Student:
    '''student class that includes information regarding a student's name, email, grades/marks'''
    def __init__(self, first_name, last_name, email_address, course_ids, grades, marks):
        self.first_name = first_name
        self.last_name = last_name
        self.email_address = email_address
        self.course_ids = course_ids
        self.grades = grades
        self.marks = marks

    @staticmethod
    def display_records():
        '''displays student records'''
        # array method
        print('Displaying students...')
        students_list = get_data('student.csv')[1]
        for student in students_list:
            print(f'''
                  {student[0]}
                  {student[1]} {student[2]}
                  Course: {student[3]}
                  Performance: {student[4]} ({student[5]}%)
                  ''')
    
    def add_new_student(self, student): # student from add_student()
        '''add a new student into the system'''
        # linked list method
        print(f'Checking system to add {student.first_name} {student.last_name}...')
        students_ll = get_data('student.csv')[0]
        student_info = [student.email_address, student.first_name, student.last_name, student.course_ids, student.grades, student.marks]
        exists = students_ll.check_for_data_in_ll(self.email_address)

        if students_ll.size() == 0:
            students_ll.add_first(student_info)
            add_to_file('student.csv', student_info)
            print(f'{student.first_name} {student.last_name} successfully added! (First student added)')

        if not exists:
            students_ll.add_new(student_info)
            add_to_file('student.csv', student_info)
            print(f'{student.first_name} {student.last_name} successfully added! (Another student added)')

    def delete_student(self, email_address):
        '''delete a student in the system using their email address'''
        # linked list method
        students_ll, student_list, header = get_data('student.csv')
        try:
            print(f'Checking system to delete student associated with email {email_address}...')
            students_ll.delete_node(email_address)
            write_to_file_ll('student.csv', header, students_ll)
        except Exception as e:
            print(f'Error deleting student: {e}!')

    def check_my_grades(self):
        '''lets student check their own grades'''
        # array method
        student_list = get_data('student.csv')[1]
        for student in student_list:
            if student[0] == self.email_address:
                print(f"You currently have a {self.grades} in {self.course_ids}")

    def update_student_record(self, new_grade, new_mark):
        '''updates a student's record by using their email address'''
        # array method
        students_ll, student_list, header = get_data('student.csv')
        for student in student_list:
            if student[0] == self.email_address:
                student[4] = self.grades = new_grade 
                student[5] = self.marks = new_mark 
        write_to_file_array('student.csv', header, student_list)
        print(f'The grade and mark for {self.first_name} {self.last_name} has been updated to {self.grades} ({self.marks}%)')

    def check_my_marks(self):
        '''lets student check their own marks'''
        # array method
        student_list = get_data('student.csv')[1]
        for student in student_list:
            if student[0] == self.email_address:
                print(f"You currently have a mark of {self.marks}% in {self.course_ids}")

    @staticmethod
    def sort_students(by, order):
        '''sorts students either by email or grade'''
        student_list = get_data('student.csv')[1]
        sorted_list = sorted(student_list, key = lambda x: x[0]) if by == 'email' else sorted(student_list, key = lambda x: x[5])
        if order == 'reverse':
            sorted_list = sorted_list[::-1]
        for student in sorted_list:
            print(f'''
                  {student[0]}
                  {student[2]}, {student[1]}
                  Enrolled in: {student[3]}
                  Current grade for {student[3]}: {student[4]}
                  Mark: {student[5]}
                  ''')
        
class Course:
    '''course class that includes information regarding a course's id, credits, name'''
    def __init__(self, course_id, credits, course_name, course_description):
        self.course_id = course_id
        self.credits = credits
        self.course_name = course_name
        self.course_description = course_description

    @staticmethod # static to call out of course object
    def display_courses():
        '''displays all courses'''
        print('Displaying courses...')
        courses_list = get_data('course.csv')[1]
        for course in courses_list:
            print(f'''
                  {course[0]}
                  Name: {course[1]}
                  Credits: {course[2]}
                  Description: {course[3]}
                  ''')

    def add_new_course(self, course): # course from add_course()
        '''add a new course'''
        print(f'Checking system to add {course.course_id}...')
        courses_ll = get_data('course.csv')[0]
        course_info = [course.course_id, course.credits, course.course_name, course.course_description]
        exists = courses_ll.check_for_data_in_ll(self.course_id)

        if courses_ll.size() == 0:
            courses_ll.add_first(course_info)
            add_to_file('course.csv', course_info)
            print(f'{course.course_id} successfully added! (First course added)')

        if not exists:
            courses_ll.add_new(course_info)
            add_to_file('course.csv', course_info)
            print(f'{course.course_id} successfully added! (Another course added)')

    def delete_course(self, id):
        '''delete a course using its id'''
        courses_ll, course_list, header = get_data('course.csv')
        try:
            print(f'Checking system to delete course associated with the course id {id}...')
            courses_ll.delete_node(id)
            write_to_file_ll('course.csv', header, courses_ll)
        except Exception as e:
            print(f'Error deleting course: {e}!')
    
class Professor:
    '''professor class that includes information regarding a professor's name, email, rank'''
    def __init__(self, email_address, name, rank, course_id):
        self.name = name
        self.email_address = email_address
        self.rank = rank
        self.course_id = course_id

    @staticmethod
    def professors_details():
        '''displays all professors'''
        print('Displaying professor details...')
        professors_list = get_data('professor.csv')[1]
        for professor in professors_list:
            print(f'''
                  {professor[0]}
                  {professor[1]}
                  Rank: {professor[2]}
                  Currently Teaching: {professor[3]}
                  ''')

    def add_new_professor(self, professor): # professor from add_professor()
        '''add a new professor into the system'''
        print(f'Checking system to add {professor.name}...')
        professors_ll = get_data('professor.csv')[0]
        professor_info = [professor.email_address, professor.name, professor.rank, professor.course_id]
        exists = professors_ll.check_for_data_in_ll(self.email_address)

        if professors_ll.size() == 0:
            professors_ll.add_first(professor_info)
            add_to_file('professor.csv', professor_info)
            print(f'{professor.name} successfully added! (First professor added)')

        if not exists:
            professors_ll.add_new(professor_info)
            add_to_file('professor.csv', professor_info)
            print(f'{professor.name} successfully added! (Another professor added)')
    
    def delete_professor(self, email_address):
        '''delete a professor using their email address'''
        professors_ll, professor_list, header = get_data('professor.csv')
        try:
            print(f'Checking system to delete professor associated with the email {email_address}...')
            professors_ll.delete_node(email_address)
            write_to_file_ll('professor.csv', header, professors_ll)
        except Exception as e:
            print(f'Error deleting professor: {e}!')

    def modify_professor_details(self, new_rank):
        '''modify a professor in the system using their email address'''
        professors_ll, professor_list, header = get_data('professor.csv')
        for professor in professor_list:
            if professor[0] == self.email_address:
                professor[2] = self.rank = new_rank
        write_to_file_array('professor.csv', header, professor_list)
        print(f'The rank for {self.name} has been updated to {self.rank}')

    def show_course_details_by_professor(self):
        '''show a professor's course using their email address'''
        professor_list = get_data('professor.csv')[1]
        course_list = get_data('course.csv')[1]
        for professor in professor_list:
            if professor[0] == self.email_address:
                for course in course_list:
                    if professor[3] == course[0]:
                        print(f'''
                              Showing course details for {professor[1]}:
                              ID: {course[0]}
                              Name: {course[1]}
                              Credits: {course[2]}
                              Description: {course[3]}
                              '''
                        )

class Grades:
    '''grades class that includes information regarding a specific grade for a student'''
    def __init__(self, grade_id, grade, mark, course_id = None):
        self.grade_id = grade_id # email address to match with the student it is assigned to
        self.grade = grade
        self.mark = mark

    @staticmethod
    def get_grades():
        student_grades = get_data('student.csv')[1]
        grade_data = [[student_grades[student][0], student_grades[student][4], student_grades[student][5], student_grades[student][3]] for student in range(len(student_grades))]
        return grade_data
    
    @staticmethod
    def display_grade_report():
        '''displays a report of all the grades for students'''
        grades = Grades.get_grades()
        for grade in grades:
            grade_id = grade[0]
            grade_id = Grades(grade[0], grade[1], grade[2], grade[3])
            print(f'{grade_id.grade_id}: {grade_id.grade} / {grade_id.mark}% / {grade[3]}')

    @staticmethod
    def display_grades_by_course(course):
        grades = Grades.get_grades()
        course_grades = []
        for grade in grades:
            if grade[3] == course:
                course_grades.append(grade[2])
                print(f'{grade[0]}: {grade[1]} ({grade[2]}%)')
        
        print(f'There are {len(course_grades)} students in {course}.')

    @staticmethod
    def get_course_average(course):
        course_grades = []
        grades = Grades.get_grades()
        for grade in grades:
                if grade[3] == course:
                    course_grades.append(int(grade[2]))
        class_average = sum(course_grades) / len(course_grades)
        return class_average

class Node:
    def __init__(self, data):
        self.data = data 
        self.next = None 

class LinkedList:
    '''linked list class that allows for efficient insertion/deletion/sorting of data'''
    def __init__(self):
        self.head = None
    
    def check_head(self):
        return True if self.head is not None else False
    
    def check_for_data_in_ll(self, data):
        if self.check_head():
            c1 = self.head
            while c1 is not None:
                if c1.data[0] == data:
                    print(f'{data} already exists in the system!')
                    return True
                else:
                    c1 = c1.next
                    
            return False
    
    def add_first(self, data):
        '''add first node if linked list is empty'''
        if self.head is None: 
            self.head = Node(data)
        else:
            c1 = self.head 
            self.head = Node(data) 
            self.head.next = c1 

    def add_new(self, data):
        '''add node at last position'''
        if self.head is None:
            self.head = Node(data)
        else:
            c1 = self.head
            while c1.next is not None:
                c1 = c1.next 
            c1.next = Node(data) 

    def print(self):
        '''print the  linked list'''
        if self.check_head(): 
           c1 = self.head
        if self.head is not None:
            c1 = self.head
            while c1 is not None:
                print(c1.data)
                c1 = c1.next 

    def size(self):
        '''get the size of linked list'''
        count=0
        c1 = self.head
        while c1:
            c1 = c1.next
            count = count + 1
        return count

    def delete_node(self, data):
        '''delete the linked list's node with specific data'''
        flag = False
        prev_node = None
        if self.check_head(): 
            c1 = self.head 
            while c1 is not None: 
                if c1.data[0] == data: 
                    print(f'Deleting {data}... \n')
                    if prev_node is None: # checking if first node; if so, move head to the next node
                        flag = True 
                        self.head = c1.next
                        print(f'{data} successfully deleted!')
                        break
                    else: # if not first node, point previous node to the node after this one
                        flag = True
                        prev_node.next = c1.next
                        print(f'{data} successfully deleted!')
                        break
                prev_node = c1
                c1 = c1.next
        else:
            print("There are currently no values to delete!")

        if not flag:
            print(f"{data} was not found in the system!")

class TestCheckMyGrade (unittest.TestCase):
    '''test cases for the above class methods'''
    def test_01_add_students(self):
        '''unit test for checking the successful addition of 1000 sturent records (using linked list)'''
        self.courses = ['DATA200', 'DATA201', 'DATA202', 'DATA203', 'DATA204']

        pre_added_students = get_data('student.csv')[1] # to keep the index of the actual data
        real_data_rows = len(pre_added_students)
        
        for i in range (0, 1000):
            first_name = 'firstname' + str(i)
            last_name = 'lastname' + str(i)
            email_address = last_name + '@myschool.edu'
            course_ids = random.choice(self.courses)
            grades = None # this will be modified in a future test
            marks = random.randint(40,100)
            test_student = Student(first_name, last_name, email_address, course_ids, grades, marks)
            test_student.add_new_student(test_student)
            post_added_students = get_data('student.csv')[1]
        
        self.assertEqual((len(post_added_students)), (real_data_rows + 1000))
        print('1000 students successfully added!')

    def test_02_modify_students(self):
        '''unit test for modifying grades of students; replaces the None values for grades of previous test with actual grades'''
        for i in range (0, 1000):
            last_name = 'lastname' + str(i)
            email_address = last_name + '@myschool.edu'
            test_student = get_student(email_address)

            new_mark = random.randint(40,100)
            if new_mark < 60:
                new_grade = 'F'
            elif 60 <= new_mark <= 64:
                new_grade = 'D-'
            elif new_mark == 65:
                new_grade = 'D'
            elif 66 <= new_mark <= 69:
                new_grade = 'D+'
            elif 70 <= new_mark <= 74:
                new_grade = 'C-'
            elif new_mark == 75:
                new_grade = 'C'
            elif 76 <= new_mark <= 79:
                new_grade = 'C+'
            elif 80 <= new_mark <= 84:
                new_grade = 'B-'
            elif new_mark == 85:
                new_grade = 'B'
            elif 86 <= new_mark <= 89:
                new_grade = 'B+'
            elif 90 <= new_mark <= 94:
                new_grade = 'A-'
            elif new_mark == 95:
                new_grade = 'A'
            elif 96 <= new_mark <= 100:
                new_grade = 'A+'
            test_student.update_student_record(new_grade, new_mark)
        
        self.assertIsNotNone(test_student.grades) # checks to see if the student grades are no longer None
        print('Student grades were modified!')
    
    def test_03_delete_students(self):
        '''unit test for deleting the 1000 sturent records (using linked list)'''
        pre_deleted_students = get_data('student.csv')[1] 
        pre_deleted_students_length = len(pre_deleted_students)
        
        for i in range (0, 1000):
            last_name = 'lastname' + str(i)
            email_address = last_name + '@myschool.edu'
            test_student = Student(first_name = None, last_name = None, email_address = None, course_ids = None, grades = None, marks = None)
            test_student.delete_student(email_address)
            post_deleted_students = get_data('student.csv')[1]
        
        self.assertEqual((len(post_deleted_students)), (pre_deleted_students_length - 1000), 'After 1000 students inserted') 
        print('1000 students were deleted!')

    def test_04_load_file(self):
        '''unit test for checking to see if students from student.csv file were successfully loaded'''
        students_from_file = get_data('student.csv')[0] 
        self.assertGreater(students_from_file.size(), 0)
        print('Student loaded from file successfully')
    
    def test_05_search_from_loaded_file(self):
        '''unit test for timing searches of certain students'''
        print('Searching for students...')
        starting_time_1 = time.time()
        searched_student_1 = get_student('mae@myschool.edu') # get_student inherently calls loads the file (uses get_data function)
        print(f'Amount of time it took to find {searched_student_1.first_name} {searched_student_1.last_name}: {(time.time() - starting_time_1)} seconds')

        starting_time_2 = time.time()
        searched_student_2 = get_student('smith@myschool.edu')
        print(f'Amount of time it took to find {searched_student_2.first_name} {searched_student_2.last_name}: {(time.time() - starting_time_2)} seconds')
    
    def test_06_sort_students(self):
        '''unit test for sorting students by email (asc and desc order)'''
        starting_time_1 = time.time()
        Student.sort_students('email', 'default') # ascending/default
        print(f'Amount of time it took to sort in ascending order: {(time.time() - starting_time_1)} seconds')

        starting_time_2 = time.time()
        Student.sort_students('email', 'reverse') # descending
        print(f'Amount of time it took to sort in ascending order: {(time.time() - starting_time_2)} seconds')

    def test_07_add_delete_course(self):
        '''unit test that checks if a course has been added/modified/deleted'''
        # add course
        test_course = Course('DATA1000',3,'Data Test Course', 'Test course')
        test_course.add_new_course(test_course)

        courses = get_data('course.csv')[1]
        course_ids = [course[0] for course in courses]

        self.assertIn('DATA1000', course_ids) 
        print('Course added successfully!')
    
        # delete course
        test_course.delete_course('DATA1000')
        updated_courses = get_data('course.csv')[1]
        updated_course_ids = [course[0] for course in updated_courses]
        self.assertNotIn('DATA1000', updated_course_ids) 
        print('Course deleted successfully!')

    def test_08_add_modify_delete_professor(self):
        '''unit test that checks if a professor has been added/modified/deleted'''
        # add professor
        test_professor = Professor('professor@myschool.edu', 'Test Professor', 'Lecturer', 'DATA1000')
        test_professor.add_new_professor(test_professor)

        professors = get_data('professor.csv')[1]
        professor_ids = [professor[0] for professor in professors]

        self.assertIn('professor@myschool.edu', professor_ids) 
        print('Professor added successfully!')

        # modify professor
        test_professor.modify_professor_details('Tenured Lecturer')
        self.assertIsNot('Lecturer', test_professor.rank) # check if the professor object's rank was modified
        print('Professor updated successfully!')
    
        # delete professor
        test_professor.delete_professor('professor@myschool.edu')
        updated_professors = get_data('professor.csv')[1]
        updated_professor_ids = [professor[0] for professor in updated_professors]
        self.assertNotIn('professor@myschool.edu', updated_professor_ids) 
        print('Professor deleted successfully!')


# HELPER FUNCTIONS
def get_data(file):
    # linked list method
    data_ll = LinkedList()
    with open(file, newline = '') as csvfile:
        dataset = csv.reader(csvfile)
        header = next(dataset)
        for data in dataset:
            data_ll.add_new(data)

    # array method
    data_list = []
    c1 = data_ll.head
    while c1:
        data_list.append(c1.data)
        c1 = c1.next
    
    return data_ll, data_list, header

def add_student():
    '''gets student details for add_new_student()'''
    first_name = input('Enter first name of student: ')
    last_name = input('Enter last name of student: ')
    email_address = input('Enter email of student: ')
    course_ids = input('Enter the course that the student is enrolled in: ')
    grades = input('Enter the grade the student has in the course: ')
    marks = input('Enter the mark in integer form of the student: ')
    return first_name.strip(), last_name.strip(), email_address.strip(), course_ids.strip(), grades.strip(), marks.strip()

def get_student(email_address):
    '''get one student's details'''
    student_list = get_data('student.csv')[1]
    for student in student_list:
        if student[0] == email_address:
            current_student = Student(student[1], student[2], student[0], student[3], student[4], student[5])
            return current_student
    else:
        print('No student found with the email!')
        return None

def get_professor(email_address):
    '''get one professor's details'''
    professor_list = get_data('professor.csv')[1]
    for professor in professor_list:
        if professor[0] == email_address:
            current_professor = Professor(professor[0], professor[1], professor[2], professor[3])
            return current_professor
    else:
        print('No professor found with the email!')
        return None

def add_course():
    '''gets course details for add_new_course()'''
    course_id = input('Enter id of the course: ') # i.e. DATA200
    str_credits = input('Enter the number of credits of the course: ')
    course_name = input('Enter the name of the course: ')
    course_description = input('Enter the description of the course: ')
    try:
        credits = int(str_credits)
        if credits > 0:
            return course_id.strip(), credits, course_name.strip(), course_description.strip()
        else:
            print('Credits must be a non-zero/non-negative number!')
    except ValueError:
        print('Credits are invalid! Enter a valid integer!')

def add_professor():
    '''gets professor details for add_new_professor()'''
    name = input('Enter the name of the professor: ')
    email_address = input('Enter the email of the professor: ')
    rank = input('Enter the rank of the professor: ')
    course_id = input('Enter the course id of the course the professor teaches: ')
    return email_address.strip(), name.strip(), rank.strip(), course_id.strip()

def add_grade():
    '''gets grade details for add_new_grade()'''
    id = input('Enter id of the grade: ') 
    grade = input('Enter the grade: ') # letter grade 
    mark = input('Enter mark: ') # integer percentage
    return id.strip(), grade.strip(), int(mark.strip())

def add_to_file(file, data): 
    '''add new line to given file with data'''
    with open(file, 'a', newline = '') as writingfile:
        writer = csv.writer(writingfile)
        writer.writerow(data)

def write_to_file_array(file, header, data): 
    '''rewrite to given file with data using array'''
    with open(file, 'w', newline = '') as writingfile:
        writer = csv.writer(writingfile)
        writer.writerow(header)
        writer.writerows(data)

def write_to_file_ll(file, header, data): 
    '''rewrite to given file with data using linked list'''
    formatted_data = []
    formatted_data.append(header)
    c1 = data.head

    while c1:
        formatted_data.append(c1.data)
        c1 = c1.next

    with open(file, 'w', newline = '') as writingfile:
        writer = csv.writer(writingfile)
        writer.writerows(formatted_data)

# %% [markdown]
# # Testing

# %% [markdown]
# ## LoginUser

# %%
if __name__ == "__main__":
    ####### LOGINUSER
    # logging in
    email_address = input("Enter your email address: ")
    password = input("Enter your password: ")
    login = LoginUser(email_address.strip(),password.strip())
    login.login()
    login.change_password()
# Out:
# You are now logged in!
# admin@myschool.edu: tvsjiwwsvi
# Your password has been updated! Please try logging in with your new password...

# %% [markdown]
# ## Student

# %%
####### STUDENT
# displaying student records
Student.display_records()
# Out:
# Displaying students...
#
#                   mae@myschool.edu
#                   Samantha Mae
#                   Course: DATA200
#                   Performance: B- (80%)
#
#
#                   russell@myschool.edu
#                   Sally Russell
#                   Course: DATA200
#                   Performance: A- (90%)
#
#
#                   doe@myschool.edu
#                   John Doe
#                   Course: DATA201
#                   Performance: A- (93%)
#
#
#                   smith@myschool.edu
#                   Jane Smith
#                   Course: DATA202
#                   Performance: B+ (88%)
#
#
#                   jones@myschool.edu
#                   Emily Jones
#                   Course: DATA203
#                   Performance: A- (92%)
#
#
#                   brown@myschool.edu
#                   Michael Brown
#                   Course: DATA204
#                   Performance: B (85%)
#
#
#                   davis@myschool.edu
#                   Sarah Davis
#                   Course: DATA203
#                   Performance: A (97%)
#
#
#                   miller@myschool.edu
#                   William Miller
#                   Course: DATA201
#                   Performance: C- (72%)
#
#
#                   wilson@myschool.edu
#                   Lucy Wilson
#                   Course: DATA202
#                   Performance: B- (80%)
#
#
#                   moore@myschool.edu
#                   Charles Moore
#                   Course: DATA200
#                   Performance: A (94%)
#
#
#                   taylor@myschool.edu
#                   Olivia Taylor
#                   Course: DATA204
#                   Performance: B+ (89%)
#
#
#                   anderson@myschool.edu
#                   Benjamin Anderson
#                   Course: DATA201
#                   Performance: C (75%)
#
#
#                   johnson@myschool.edu
#                   Jack Johnson
#                   Course: DATA200
#                   Performance: D+ (68%)

# %%
# adding new student
first_name, last_name, email_address = add_student()
new_student = Student(first_name, last_name, email_address)
new_student.add_new_student(new_student)
# Out:
# Checking system to add Jack Johnson...
# Jack Johnson successfully added! (Another student added)

# %%
# deleting student
email_address = input('Enter the email address of the student to be deleted: ')
delete_student = Student(first_name = None, last_name = None, email_address = None)
delete_student.delete_student(email_address)
# Out:
# Checking system to delete student associated with email a...
# Deleting a...
#
# a successfully deleted!

# %%
# student checking grades/marks and update
current_student = get_student('mae@myschool.edu')
current_student.check_my_grades()
current_student.check_my_marks()
current_student.update_student_record('B', '85')
# Out:
# You currently have a B in DATA200
# You currently have a mark of 85% in DATA200
# The grade and mark for Samantha Mae has been updated to B (85%)

# %%
# sorting students
sort_by = input('''How would you like to sort?
                1. By student ID (email address)
                2. By grade''')
Student.sort_students('email') if sort_by == '1' else Student.sort_students('grade') if sort_by == '2' else print('Incorrect input for sorting!')
# Out:
#                   miller@myschool.edu
#                   Miller, William
#                   Enrolled in: DATA201
#                   Current grade for DATA201: C-
#                   Mark: 72
#
#
#                   anderson@myschool.edu
#                   Anderson, Benjamin
#                   Enrolled in: DATA201
#                   Current grade for DATA201: C
#                   Mark: 75
#
#
#                   wilson@myschool.edu
#                   Wilson, Lucy
#                   Enrolled in: DATA202
#                   Current grade for DATA202: B-
#                   Mark: 80
#
#
#                   brown@myschool.edu
#                   Brown, Michael
#                   Enrolled in: DATA204
#                   Current grade for DATA204: B
#                   Mark: 85
#
#
#                   mae@myschool.edu
#                   Mae, Samantha
#                   Enrolled in: DATA200
#                   Current grade for DATA200: B+
#                   Mark: 88
#
#
#                   smith@myschool.edu
#                   Smith, Jane
#                   Enrolled in: DATA202
#                   Current grade for DATA202: B+
#                   Mark: 88
#
#
#                   taylor@myschool.edu
#                   Taylor, Olivia
#                   Enrolled in: DATA204
#                   Current grade for DATA204: B+
#                   Mark: 89
#
#
#                   russell@myschool.edu
#                   Russell, Sally
#                   Enrolled in: DATA200
#                   Current grade for DATA200: A-
#                   Mark: 91
#
#
#                   jones@myschool.edu
#                   Jones, Emily
#                   Enrolled in: DATA203
#                   Current grade for DATA203: A-
#                   Mark: 92
#
#
#                   moore@myschool.edu
#                   Moore, Charles
#                   Enrolled in: DATA200
#                   Current grade for DATA200: A
#                   Mark: 94
#
#
#                   doe@myschool.edu
#                   Doe, John
#                   Enrolled in: DATA201
#                   Current grade for DATA201: A
#                   Mark: 95
#
#
#                   davis@myschool.edu
#                   Davis, Sarah
#                   Enrolled in: DATA203
#                   Current grade for DATA203: A
#                   Mark: 97

# %% [markdown]
# ## Courses

# %%
####### COURSES
# displaying courses
Course.display_courses()
# Out:
# Displaying courses...
#
#                   DATA200
#                   Name: Intro to Data Science
#                   Credits: 3
#                   Description: Utilizing Python in Data Science
#
#
#                   DATA201
#                   Name: Intro to Databases
#                   Credits: 3
#                   Description: Utilizing SQL in Data Science
#
#
#                   DATA203
#                   Name: Advanced Database Techniques
#                   Credits: 3
#                   Description: Learn about advanced SQL queries and processing pipelines

# %%
# adding new course
course_id, course_name, course_credits, course_description = add_course()
new_course = Course(course_id, course_credits, course_name, course_description)
new_course.add_new_course(new_course)
# Out:
# Checking system to add DATA203...
# DATA203 already exists in the system!

# %%
# deleting course
course_id = input('Enter the course id to be deleted: ')
delete_course = Course(course_id = None, credits = None, course_name = None, course_description = None)
delete_course.delete_course(course_id)
# Out:
# Checking system to delete course associated with the course id DATA203...
# Deleting DATA203...
#
# DATA203 successfully deleted!

# %% [markdown]
# ## Professors

# %%
####### PROFESSORS
# displaying professors
Professor.professors_details()
# Out:
# Displaying professor details...
#
#                   smith@myschool.edu
#                   John Smith
#                   Rank: Tenured Lecturer
#                   Currently Teaching: DATA200
#
#
#                   douglas@myschool.edu
#                   Ken Douglas
#                   Rank: Visiting Lecturer
#                   Currently Teaching: DATA201
#
#
#                   roberts@myschool.edu
#                   Dave Roberts
#                   Rank: Visiting Scholar
#                   Currently Teaching: DATA203
#
#
#                   gomez@myschool.edu
#                   Kerry Gomez
#                   Rank: Adjunct Lecturer
#                   Currently Teaching: DATA202

# %%
# adding new professor
email_address, name, rank, course_id = add_professor()
new_professor = Professor(email_address, name, rank, course_id)
new_professor.add_new_professor(new_professor)
# Out:
# Checking system to add Dave Roberts...
# Dave Roberts successfully added! (Another professor added)
# ['smith@myschool.edu', 'John Smith', 'Tenured Lecturer', 'DATA200']
# ['douglas@myschool.edu', 'Ken Douglas', 'Tenured Lecturer', 'DATA201']
# ['roberts@myschool.edu', 'Dave Roberts', 'Visiting Lecturer', 'DATA203']

# %%
# deleting a professor
email_address = input('Enter the email address of the professor to be deleted: ')
delete_professor = Professor(email_address = None, name = None, rank = None, course_id = None)
delete_professor.delete_professor(email_address)
# Out:
# Checking system to delete professor associated with the email roberts@myschool.edu...
# Deleting roberts@myschool.edu...
#
# roberts@myschool.edu successfully deleted!

# %%
# update a professor's details
current_professor = get_professor()
current_professor.modify_professor_details('Tenured Lecturer')
# Out:
# The rank for Dave Roberts has been updated to Tenured Lecturer

# %%
# show course details of a professor
current_professor = get_professor()
current_professor.show_course_details_by_professor()
# Out:
#                               Showing course details for Ken Douglas:
#                               ID: DATA201
#                               Name: Intro to Databases
#                               Credits: 3
#                               Description: Utilizing SQL in Data Science

# %% [markdown]
# ## Grades

# %%
####### GRADES
# display all grades and their associated student id
Grades.display_grade_report()
print()
Grades.display_grades_by_course('DATA200')
# Out:
# mae@myschool.edu: B+ / 88% / DATA200
# russell@myschool.edu: A- / 91% / DATA200
# doe@myschool.edu: A / 95% / DATA201
# smith@myschool.edu: B+ / 88% / DATA202
# jones@myschool.edu: A- / 92% / DATA203
# brown@myschool.edu: B / 85% / DATA204
# davis@myschool.edu: A / 97% / DATA203
# miller@myschool.edu: C- / 72% / DATA201
# wilson@myschool.edu: B- / 80% / DATA202
# moore@myschool.edu: A / 94% / DATA200
# taylor@myschool.edu: B+ / 89% / DATA204
# anderson@myschool.edu: C / 75% / DATA201
#
# mae@myschool.edu: B+ (88%)
# russell@myschool.edu: A- (91%)
# moore@myschool.edu: A (94%)
# There are 3 grade entries for DATA200.

# %%
def checkmygrade_main_menu():
    while True:
        columns = shutil.get_terminal_size().columns
        print('================================='.center(columns))
        print('Welcome to CheckMyGrade'.center(columns))
        print('================================'.center(columns))
        print('\n CheckMyGrade Menu:')
        print('1. Login')
        print('2. Exit')
        choice = input('Enter your choice: ')
        if choice == '1':
            print('Logging in...')
            email_address = input('Enter your email address: ')
            password = getpass.getpass('Enter your password: ')
            current_user = LoginUser(email_address.strip(), password.strip())
            status, email_address, role = current_user.login()
            print(status, email_address, role) 
            if status:
                if role == 'student':
                    current_student = get_student(current_user.email_address)
                    while True:
                        print('================================='.center(columns))
                        msg='''Welcome to CheckMyGrade'''
                        print(msg.center(columns))
                        msg2='''Student Portal'''
                        print(msg2.center(columns))
                        print('================================'.center(columns))
                        print('\n CheckMyGrade Main Menu:')
                        print('1. Check my grade')
                        print('2. Check my mark')
                        print("3. Compare my mark against course average")
                        print('4. Change my password')
                        print('5. Logout')
                        choice = input('Enter what you would like to do: ')
                        if choice == '1':
                            print('Checking your grade...')
                            current_student.check_my_grades()
                        elif choice == '2':
                            print('Checking your mark...')
                            current_student.check_my_marks()
                        elif choice == '3':
                            print('Getting information for comparison...')
                            print(f'You current mark in {current_student.course_ids} is {current_student.marks}%')
                            course_average = Grades.get_course_average(current_student.course_ids)
                            print(f'The current class average is {course_average}%')
                            print('Keep it up!') if int(current_student.marks) >= course_average else print('Keep your head up!') 
                        elif choice == '4':
                            print('Changing your password...')
                            current_user.change_password()
                        elif choice == '5':
                            print('Logging out...')
                            current_user.logout()
                            return False
                        else:
                            print('Enter a valid choice!')
                elif role == 'professor':
                    current_professor = get_professor(current_user.email_address)
                    while True:
                        print('================================='.center(columns))
                        msg='''Welcome to CheckMyGrade'''
                        print(msg.center(columns))
                        msg2='''Professor Portal'''
                        print(msg2.center(columns))
                        print('================================'.center(columns))
                        print('\n CheckMyGrade Main Menu:')
                        print('1. Check my course')
                        print('2. Get grade report for my course')
                        print('3. Change student grades/marks')
                        print('4. Change my password')
                        print('5. Logout')
                        choice = input('Enter what you would like to do: ')
                        if choice == '1':
                            print('Retrieving your course details...')
                            current_professor.show_course_details_by_professor()
                        elif choice == '2':
                            print(f'Getting grade report for your course ({current_professor.course_id})...')
                            Grades.display_grades_by_course(current_professor.course_id)
                            course_average = Grades.get_course_average(current_professor.course_id)
                            print(f'Course average: {course_average}%')
                        elif choice == '3':
                            print('Showing list of students in your course...')
                            Grades.display_grades_by_course(current_professor.course_id)
                            student_email = input('Enter the email of the student you would like to edit: ')
                            update_student = get_student(student_email)
                            if update_student:
                                print(f'The current grade and mark for {update_student.first_name} {update_student.last_name} is {update_student.grades} ({update_student.marks}%)')
                                new_mark = input(f'Enter the new mark for {update_student.first_name} {update_student.last_name}: ')
                                if isinstance(int(new_mark), int):
                                    if 0 <= int(new_mark) <= 100:
                                        new_grade = input(f'Enter the new grade for {update_student.first_name} {update_student.last_name}: ')
                                        update_student.update_student_record(new_grade, new_mark)
                                    else:
                                        print('New mark must be valid (between 0 to 100!)')
                                else:
                                    print('Please enter a valid integer!')
                            else:
                                print('Please try again!')
                        elif choice == '4':
                            print('Changing your password...')
                            current_user.change_password()
                        elif choice == '5':
                            print('Logging out...')
                            current_user.logout()
                            break
                        else:
                            print('Enter a valid choice!')
                elif role == 'admin':
                    while True:
                        print('================================='.center(columns))
                        msg='''Welcome to CheckMyGrade'''
                        print(msg.center(columns))
                        msg2='''Admin Portal'''
                        print(msg2.center(columns))
                        print('================================'.center(columns))
                        print('1. Display all students')
                        print('2. Display all courses')
                        print('3. Display all professors')
                        print('4. Sort students')
                        print('5. Search students')
                        print('6. Add student')
                        print('7. Delete student')
                        print('8. Add course')
                        print('9. Delete course')
                        print('10. Add professor')
                        print('11. Delete professor')
                        print('12. Update professor rank')
                        print('13. Logout')
                        choice = input('Enter what you would like to do: ')
                        if choice == '1':
                            print('Retrieving all students...')
                            Student.display_records()
                        elif choice == '2':
                            print('Retrieving all courses...')
                            Course.display_courses()
                        elif choice == '3':
                            print('Retrieving all professors...')
                            Professor.professors_details()
                        elif choice == '4':
                            print('Sort students...')
                            sort_by = input('''How would you like to sort?
                                            1. By student ID (email address) 
                                            2. By student ID (email address) (reversed)
                                            3. By grade
                                            4. By grade (descending)
                                            ''')
                            if sort_by == '1':
                                Student.sort_students('email', 'default')
                            elif sort_by == '2':
                                Student.sort_students('email', 'reverse')
                            elif sort_by == '3':
                                Student.sort_students('grade', 'default')
                            elif sort_by == '4':
                                Student.sort_students('grade', 'reverse')
                            else:
                                print('Incorrect input for sorting!')
                        elif choice == '5':
                            print('Search for student...')
                            student_id = input('Enter student email: ')
                            searched_student = get_student(student_id)
                            if searched_student is not None:
                                print(f'Displaying information for {searched_student.first_name} {searched_student.last_name}')
                                print(f'''
                                    Enrolled in: {searched_student.course_ids}
                                    Grade in {searched_student.course_ids}: {searched_student.grades}
                                    Mark: {searched_student.marks}
                                    ''')
                                course_average = Grades.get_course_average(searched_student.course_ids)
                                print(f'{searched_student.first_name} {searched_student.last_name} is currently above the course average ({course_average})') if int(searched_student.marks) >= course_average else print(f'{searched_student.first_name} {searched_student.last_name} is currently below the course average ({course_average})')
                            else: 
                                print('Invalid student email!')
                        elif choice == '6':
                            print('Adding student...')
                            first_name, last_name, email_address, course_ids, grades, marks = add_student()
                            new_student = Student(first_name, last_name, email_address, course_ids, grades, marks)
                            new_student.add_new_student(new_student)
                        elif choice == '7':
                            print('Deleting student...')
                            email_address = input('Enter the email address of the student to be deleted: ')
                            delete_student = Student(first_name = None, last_name = None, email_address = None, course_ids = None, grades = None, marks = None)
                            delete_student.delete_student(email_address)
                        elif choice == '8':
                            print('Adding course...')
                            course_id, course_name, course_credits, course_description = add_course()
                            new_course = Course(course_id, course_credits, course_name, course_description)
                            if new_course:
                                new_course.add_new_course(new_course)
                            else:
                                print('Issue adding course! Make sure you are entering the course details correctly.')
                        elif choice == '9':
                            print('Deleting course...')
                            course_id = input('Enter the course id to be deleted: ')
                            delete_course = Course(course_id = None, credits = None, course_name = None, course_description = None)
                            delete_course.delete_course(course_id)
                        elif choice == '10':
                            print('Adding professor...')
                            email_address, name, rank, course_id = add_professor()
                            new_professor = Professor(email_address, name, rank, course_id)
                            new_professor.add_new_professor(new_professor)
                        elif choice == '11':
                            print('Deleting professor...')
                            email_address = input('Enter the email address of the professor to be deleted: ')
                            delete_professor = Professor(email_address = None, name = None, rank = None, course_id = None)
                            delete_professor.delete_professor(email_address)
                        elif choice == '12':
                            print('Update professor details...')
                            email_address = input('Enter the email address of the professor you wish to modify: ')
                            update_professor = get_professor(email_address)
                            if update_professor:
                                new_rank = input(f'Enter the new rank of {update_professor.name}')
                                update_professor.modify_professor_details(new_rank)
                            else:
                                print('Professor not found! Make sure you entered their email correctly.')
                        elif choice == '13':
                            print('Logging out...')
                            current_user.logout()
                            break
                        else: 
                            print('Enter a valid choice!')
                        
        elif choice == '2':
            print('Exiting CheckMyGrade... Goodbye!')
            break
        else:
            print('Invalid choice! Please try again.')

if __name__ == '__main__':
    checkmygrade_main_menu()
# Out:
#                        =================================
#                             Welcome to CheckMyGrade
#                         ================================
#
#  CheckMyGrade Menu:
# 1. Login
# 2. Exit
# Logging in...
# Checking next...
# Checking next...
# Unable to login! Returning to login screen...
# False None None
#                        =================================
#                             Welcome to CheckMyGrade
#                         ================================
#
#  CheckMyGrade Menu:
# 1. Login
# 2. Exit
# Exiting CheckMyGrade... Goodbye!

# %%
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# Checking system to add firstname0 lastname0...
# firstname0 lastname0 successfully added! (Another student added)
# Checking system to add firstname1 lastname1...
# firstname1 lastname1 successfully added! (Another student added)
# Checking system to add firstname2 lastname2...
# firstname2 lastname2 successfully added! (Another student added)
# Checking system to add firstname3 lastname3...
# firstname3 lastname3 successfully added! (Another student added)
# Checking system to add firstname4 lastname4...
# firstname4 lastname4 successfully added! (Another student added)
# Checking system to add firstname5 lastname5...
# firstname5 lastname5 successfully added! (Another student added)
# Checking system to add firstname6 lastname6...
# firstname6 lastname6 successfully added! (Another student added)
# Checking system to add firstname7 lastname7...
# firstname7 lastname7 successfully added! (Another student added)
# Checking system to add firstname8 lastname8...
# firstname8 lastname8 successfully added! (Another student added)
# Checking system to add firstname9 lastname9...
# firstname9 lastname9 successfully added! (Another student added)
# Checking system to add firstname10 lastname10...
# firstname10 lastname10 successfully added! (Another student added)
# Checking system to add firstname11 lastname11...
# firstname11 lastname11 successfully added! (Another student added)
# Checking system to add firstname12 lastname12...
# firstname12 lastname12 successfully added! (Another student added)
# Checking system to add firstname13 lastname13...
# firstname13 lastname13 successfully added! (Another student added)
# Checking system to add firstname14 lastname14...
# firstname14 lastname14 successfully added! (Another student added)
# Checking system to add firstname15 lastname15...
# firstname15 lastname15 successfully added! (Another student added)
# Checking system to add firstname16 lastname16...
# firstname16 lastname16 successfully added! (Another student added)
# Checking system to add firstname17 lastname17...
# firstname17 lastname17 successfully added! (Another student added)
# Checking system to add firstname18 lastname18...
# firstname18 lastname18 successfully added! (Another student added)
# Checking system to add firstname19 lastname19...
# firstname19 lastname19 successfully added! (Another student added)
# Checking system to add firstname20 lastname20...
# firstname20 lastname20 successfully added! (Another student added)
# Checking system to add firstname21 lastname21...
# firstname21 lastname21 successfully added! (Another student added)
# Checking system to add firstname22 lastname22...
# firstname22 lastname22 successfully added! (Another student added)
# Checking system to add firstname23 lastname23...
# firstname23 lastname23 successfully added! (Another student added)
# Checking system to add firstname24 lastname24...
# firstname24 lastname24 successfully added! (Another student added)
# Checking system to add firstname25 lastname25...
# firstname25 lastname25 successfully added! (Another student added)
# Checking system to add firstname26 lastname26...
# firstname26 lastname26 successfully added! (Another student added)
# Checking system to add firstname27 lastname27...
# firstname27 lastname27 successfully added! (Another student added)
# Checking system to add firstname28 lastname28...
# firstname28 lastname28 successfully added! (Another student added)
# Checking system to add firstname29 lastname29...
# firstname29 lastname29 successfully added! (Another student added)
# Checking system to add firstname30 lastname30...
# firstname30 lastname30 successfully added! (Another student added)
# Checking system to add firstname31 lastname31...
# firstname31 lastname31 successfully added! (Another student added)
# Checking system to add firstname32 lastname32...
# firstname32 lastname32 successfully added! (Another student added)
# Checking system to add firstname33 lastname33...
# firstname33 lastname33 successfully added! (Another student added)
# Checking system to add firstname34 lastname34...
# firstname34 lastname34 successfully added! (Another student added)
# Checking system to add firstname35 lastname35...
# firstname35 lastname35 successfully added! (Another student added)
# Checking system to add firstname36 lastname36...
# firstname36 lastname36 successfully added! (Another student added)
# Checking system to add firstname37 lastname37...
# firstname37 lastname37 successfully added! (Another student added)
# Checking system to add firstname38 lastname38...
# firstname38 lastname38 successfully added! (Another student added)
# Checking system to add firstname39 lastname39...
# firstname39 lastname39 successfully added! (Another student added)
# Checking system to add firstname40 lastname40...
# firstname40 lastname40 successfully added! (Another student added)
# Checking system to add firstname41 lastname41...
# firstname41 lastname41 successfully added! (Another student added)
# Checking system to add firstname42 lastname42...
# firstname42 lastname42 successfully added! (Another student added)
# Checking system to add firstname43 lastname43...
# firstname43 lastname43 successfully added! (Another student added)
# Checking system to add firstname44 lastname44...
# firstname44 lastname44 successfully added! (Another student added)
# Checking system to add firstname45 lastname45...
# firstname45 lastname45 successfully added! (Another student added)
# Checking system to add firstname46 lastname46...
# firstname46 lastname46 successfully added! (Another student added)
# Checking system to add firstname47 lastname47...
# firstname47 lastname47 successfully added! (Another student added)
# Checking system to add firstname48 lastname48...
# firstname48 lastname48 successfully added! (Another student added)
# Checking system to add firstname49 lastname49...
# firstname49 lastname49 successfully added! (Another student added)
# Checking system to add firstname50 lastname50...
# firstname50 lastname50 successfully added! (Another student added)
# Checking system to add firstname51 lastname51...
# firstname51 lastname51 successfully added! (Another student added)
# Checking system to add firstname52 lastname52...
# firstname52 lastname52 successfully added! (Another student added)
# Checking system to add firstname53 lastname53...
# firstname53 lastname53 successfully added! (Another student added)
# Checking system to add firstname54 lastname54...
# firstname54 lastname54 successfully added! (Another student added)
# Checking system to add firstname55 lastname55...
# firstname55 lastname55 successfully added! (Another student added)
# Checking system to add firstname56 lastname56...
# firstname56 lastname56 successfully added! (Another student added)
# Checking system to add firstname57 lastname57...
# firstname57 lastname57 successfully added! (Another student added)
# Checking system to add firstname58 lastname58...
# firstname58 lastname58 successfully added! (Another student added)
# Checking system to add firstname59 lastname59...
# firstname59 lastname59 successfully added! (Another student added)
# Checking system to add firstname60 lastname60...
# firstname60 lastname60 successfully added! (Another student added)
# Checking system to add firstname61 lastname61...
# firstname61 lastname61 successfully added! (Another student added)
# Checking system to add firstname62 lastname62...
# firstname62 lastname62 successfully added! (Another student added)
# Checking system to add firstname63 lastname63...
# firstname63 lastname63 successfully added! (Another student added)
# Checking system to add firstname64 lastname64...
# firstname64 lastname64 successfully added! (Another student added)
# Checking system to add firstname65 lastname65...
# firstname65 lastname65 successfully added! (Another student added)
# Checking system to add firstname66 lastname66...
# firstname66 lastname66 successfully added! (Another student added)
# Checking system to add firstname67 lastname67...
# firstname67 lastname67 successfully added! (Another student added)
# Checking system to add firstname68 lastname68...
# firstname68 lastname68 successfully added! (Another student added)
# Checking system to add firstname69 lastname69...
# firstname69 lastname69 successfully added! (Another student added)
# Checking system to add firstname70 lastname70...
# firstname70 lastname70 successfully added! (Another student added)
# Checking system to add firstname71 lastname71...
# firstname71 lastname71 successfully added! (Another student added)
# Checking system to add firstname72 lastname72...
# firstname72 lastname72 successfully added! (Another student added)
# Checking system to add firstname73 lastname73...
# firstname73 lastname73 successfully added! (Another student added)
# Checking system to add firstname74 lastname74...
# firstname74 lastname74 successfully added! (Another student added)
# Checking system to add firstname75 lastname75...
# firstname75 lastname75 successfully added! (Another student added)
# Checking system to add firstname76 lastname76...
# firstname76 lastname76 successfully added! (Another student added)
# Checking system to add firstname77 lastname77...
# firstname77 lastname77 successfully added! (Another student added)
# Checking system to add firstname78 lastname78...
# firstname78 lastname78 successfully added! (Another student added)
# Checking system to add firstname79 lastname79...
# firstname79 lastname79 successfully added! (Another student added)
# Checking system to add firstname80 lastname80...
# firstname80 lastname80 successfully added! (Another student added)
# Checking system to add firstname81 lastname81...
# firstname81 lastname81 successfully added! (Another student added)
# Checking system to add firstname82 lastname82...
# firstname82 lastname82 successfully added! (Another student added)
# Checking system to add firstname83 lastname83...
# firstname83 lastname83 successfully added! (Another student added)
# Checking system to add firstname84 lastname84...
# firstname84 lastname84 successfully added! (Another student added)
# Checking system to add firstname85 lastname85...
# firstname85 lastname85 successfully added! (Another student added)
# Checking system to add firstname86 lastname86...
# firstname86 lastname86 successfully added! (Another student added)
# Checking system to add firstname87 lastname87...
# firstname87 lastname87 successfully added! (Another student added)
# Checking system to add firstname88 lastname88...
# firstname88 lastname88 successfully added! (Another student added)
# Checking system to add firstname89 lastname89...
# firstname89 lastname89 successfully added! (Another student added)
# Checking system to add firstname90 lastname90...
# firstname90 lastname90 successfully added! (Another student added)
# Checking system to add firstname91 lastname91...
# firstname91 lastname91 successfully added! (Another student added)
# Checking system to add firstname92 lastname92...
# firstname92 lastname92 successfully added! (Another student added)
# Checking system to add firstname93 lastname93...
# firstname93 lastname93 successfully added! (Another student added)
# Checking system to add firstname94 lastname94...
# firstname94 lastname94 successfully added! (Another student added)
# Checking system to add firstname95 lastname95...
# firstname95 lastname95 successfully added! (Another student added)
# Checking system to add firstname96 lastname96...
# firstname96 lastname96 successfully added! (Another student added)
# Checking system to add firstname97 lastname97...
# firstname97 lastname97 successfully added! (Another student added)
# Checking system to add firstname98 lastname98...
# firstname98 lastname98 successfully added! (Another student added)
# Checking system to add firstname99 lastname99...
# firstname99 lastname99 successfully added! (Another student added)
# Checking system to add firstname100 lastname100...
# firstname100 lastname100 successfully added! (Another student added)
# Checking system to add firstname101 lastname101...
# firstname101 lastname101 successfully added! (Another student added)
# Checking system to add firstname102 lastname102...
# firstname102 lastname102 successfully added! (Another student added)
# Checking system to add firstname103 lastname103...
# firstname103 lastname103 successfully added! (Another student added)
# Checking system to add firstname104 lastname104...
# firstname104 lastname104 successfully added! (Another student added)
# Checking system to add firstname105 lastname105...
# firstname105 lastname105 successfully added! (Another student added)
# Checking system to add firstname106 lastname106...
# firstname106 lastname106 successfully added! (Another student added)
# Checking system to add firstname107 lastname107...
# firstname107 lastname107 successfully added! (Another student added)
# Checking system to add firstname108 lastname108...
# firstname108 lastname108 successfully added! (Another student added)
# Checking system to add firstname109 lastname109...
# firstname109 lastname109 successfully added! (Another student added)
# Checking system to add firstname110 lastname110...
# firstname110 lastname110 successfully added! (Another student added)
# Checking system to add firstname111 lastname111...
# firstname111 lastname111 successfully added! (Another student added)
# Checking system to add firstname112 lastname112...
# firstname112 lastname112 successfully added! (Another student added)
# Checking system to add firstname113 lastname113...
# firstname113 lastname113 successfully added! (Another student added)
# Checking system to add firstname114 lastname114...
# firstname114 lastname114 successfully added! (Another student added)
# Checking system to add firstname115 lastname115...
# firstname115 lastname115 successfully added! (Another student added)
# Checking system to add firstname116 lastname116...
# firstname116 lastname116 successfully added! (Another student added)
# Checking system to add firstname117 lastname117...
# firstname117 lastname117 successfully added! (Another student added)
# Checking system to add firstname118 lastname118...
# firstname118 lastname118 successfully added! (Another student added)
# Checking system to add firstname119 lastname119...
# firstname119 lastname119 successfully added! (Another student added)
# Checking system to add firstname120 lastname120...
# firstname120 lastname120 successfully added! (Another student added)
# Checking system to add firstname121 lastname121...
# firstname121 lastname121 successfully added! (Another student added)
# Checking system to add firstname122 lastname122...
# firstname122 lastname122 successfully added! (Another student added)
# Checking system to add firstname123 lastname123...
# firstname123 lastname123 successfully added! (Another student added)
# Checking system to add firstname124 lastname124...
# firstname124 lastname124 successfully added! (Another student added)
# Checking system to add firstname125 lastname125...
# firstname125 lastname125 successfully added! (Another student added)
# Checking system to add firstname126 lastname126...
# firstname126 lastname126 successfully added! (Another student added)
# Checking system to add firstname127 lastname127...
# firstname127 lastname127 successfully added! (Another student added)
# Checking system to add firstname128 lastname128...
# firstname128 lastname128 successfully added! (Another student added)
# Checking system to add firstname129 lastname129...
# firstname129 lastname129 successfully added! (Another student added)
# Checking system to add firstname130 lastname130...
# firstname130 lastname130 successfully added! (Another student added)
# Checking system to add firstname131 lastname131...
# firstname131 lastname131 successfully added! (Another student added)
# Checking system to add firstname132 lastname132...
# firstname132 lastname132 successfully added! (Another student added)
# Checking system to add firstname133 lastname133...
# firstname133 lastname133 successfully added! (Another student added)
# Checking system to add firstname134 lastname134...
# firstname134 lastname134 successfully added! (Another student added)
# Checking system to add firstname135 lastname135...
# firstname135 lastname135 successfully added! (Another student added)
# Checking system to add firstname136 lastname136...
# firstname136 lastname136 successfully added! (Another student added)
# Checking system to add firstname137 lastname137...
# firstname137 lastname137 successfully added! (Another student added)
# Checking system to add firstname138 lastname138...
# firstname138 lastname138 successfully added! (Another student added)
# Checking system to add firstname139 lastname139...
# firstname139 lastname139 successfully added! (Another student added)
# Checking system to add firstname140 lastname140...
# firstname140 lastname140 successfully added! (Another student added)
# Checking system to add firstname141 lastname141...
# firstname141 lastname141 successfully added! (Another student added)
# Checking system to add firstname142 lastname142...
# firstname142 lastname142 successfully added! (Another student added)
# Checking system to add firstname143 lastname143...
# firstname143 lastname143 successfully added! (Another student added)
# Checking system to add firstname144 lastname144...
# firstname144 lastname144 successfully added! (Another student added)
# Checking system to add firstname145 lastname145...
# firstname145 lastname145 successfully added! (Another student added)
# Checking system to add firstname146 lastname146...
# firstname146 lastname146 successfully added! (Another student added)
# Checking system to add firstname147 lastname147...
# firstname147 lastname147 successfully added! (Another student added)
# Checking system to add firstname148 lastname148...
# firstname148 lastname148 successfully added! (Another student added)
# Checking system to add firstname149 lastname149...
# firstname149 lastname149 successfully added! (Another student added)
# Checking system to add firstname150 lastname150...
# firstname150 lastname150 successfully added! (Another student added)
# Checking system to add firstname151 lastname151...
# firstname151 lastname151 successfully added! (Another student added)
# Checking system to add firstname152 lastname152...
# firstname152 lastname152 successfully added! (Another student added)
# Checking system to add firstname153 lastname153...
# firstname153 lastname153 successfully added! (Another student added)
# Checking system to add firstname154 lastname154...
# firstname154 lastname154 successfully added! (Another student added)
# Checking system to add firstname155 lastname155...
# firstname155 lastname155 successfully added! (Another student added)
# Checking system to add firstname156 lastname156...
# firstname156 lastname156 successfully added! (Another student added)
# Checking system to add firstname157 lastname157...
# firstname157 lastname157 successfully added! (Another student added)
# Checking system to add firstname158 lastname158...
# firstname158 lastname158 successfully added! (Another student added)
# Checking system to add firstname159 lastname159...
# firstname159 lastname159 successfully added! (Another student added)
# Checking system to add firstname160 lastname160...
# firstname160 lastname160 successfully added! (Another student added)
# Checking system to add firstname161 lastname161...
# firstname161 lastname161 successfully added! (Another student added)
# Checking system to add firstname162 lastname162...
# firstname162 lastname162 successfully added! (Another student added)
# Checking system to add firstname163 lastname163...
# firstname163 lastname163 successfully added! (Another student added)
# Checking system to add firstname164 lastname164...
# firstname164 lastname164 successfully added! (Another student added)
# Checking system to add firstname165 lastname165...
# firstname165 lastname165 successfully added! (Another student added)
# Checking system to add firstname166 lastname166...
# firstname166 lastname166 successfully added! (Another student added)
# Checking system to add firstname167 lastname167...
# firstname167 lastname167 successfully added! (Another student added)
# Checking system to add firstname168 lastname168...
# firstname168 lastname168 successfully added! (Another student added)
# Checking system to add firstname169 lastname169...
# firstname169 lastname169 successfully added! (Another student added)
# Checking system to add firstname170 lastname170...
# firstname170 lastname170 successfully added! (Another student added)
# Checking system to add firstname171 lastname171...
# firstname171 lastname171 successfully added! (Another student added)
# Checking system to add firstname172 lastname172...
# firstname172 lastname172 successfully added! (Another student added)
# Checking system to add firstname173 lastname173...
# firstname173 lastname173 successfully added! (Another student added)
# Checking system to add firstname174 lastname174...
# firstname174 lastname174 successfully added! (Another student added)
# Checking system to add firstname175 lastname175...
# firstname175 lastname175 successfully added! (Another student added)
# Checking system to add firstname176 lastname176...
# firstname176 lastname176 successfully added! (Another student added)
# Checking system to add firstname177 lastname177...
# firstname177 lastname177 successfully added! (Another student added)
# Checking system to add firstname178 lastname178...
# firstname178 lastname178 successfully added! (Another student added)
# Checking system to add firstname179 lastname179...
# firstname179 lastname179 successfully added! (Another student added)
# Checking system to add firstname180 lastname180...
# firstname180 lastname180 successfully added! (Another student added)
# Checking system to add firstname181 lastname181...
# firstname181 lastname181 successfully added! (Another student added)
# Checking system to add firstname182 lastname182...
# firstname182 lastname182 successfully added! (Another student added)
# Checking system to add firstname183 lastname183...
# firstname183 lastname183 successfully added! (Another student added)
# Checking system to add firstname184 lastname184...
# firstname184 lastname184 successfully added! (Another student added)
# Checking system to add firstname185 lastname185...
# firstname185 lastname185 successfully added! (Another student added)
# Checking system to add firstname186 lastname186...
# firstname186 lastname186 successfully added! (Another student added)
# Checking system to add firstname187 lastname187...
# firstname187 lastname187 successfully added! (Another student added)
# Checking system to add firstname188 lastname188...
# firstname188 lastname188 successfully added! (Another student added)
# Checking system to add firstname189 lastname189...
# firstname189 lastname189 successfully added! (Another student added)
# Checking system to add firstname190 lastname190...
# firstname190 lastname190 successfully added! (Another student added)
# Checking system to add firstname191 lastname191...
# firstname191 lastname191 successfully added! (Another student added)
# Checking system to add firstname192 lastname192...
# firstname192 lastname192 successfully added! (Another student added)
# Checking system to add firstname193 lastname193...
# firstname193 lastname193 successfully added! (Another student added)
# Checking system to add firstname194 lastname194...
# firstname194 lastname194 successfully added! (Another student added)
# Checking system to add firstname195 lastname195...
# firstname195 lastname195 successfully added! (Another student added)
# Checking system to add firstname196 lastname196...
# firstname196 lastname196 successfully added! (Another student added)
# Checking system to add firstname197 lastname197...
# firstname197 lastname197 successfully added! (Another student added)
# Checking system to add firstname198 lastname198...
# firstname198 lastname198 successfully added! (Another student added)
# Checking system to add firstname199 lastname199...
# firstname199 lastname199 successfully added! (Another student added)
# Checking system to add firstname200 lastname200...
# firstname200 lastname200 successfully added! (Another student added)
# Checking system to add firstname201 lastname201...
# firstname201 lastname201 successfully added! (Another student added)
# Checking system to add firstname202 lastname202...
# firstname202 lastname202 successfully added! (Another student added)
# Checking system to add firstname203 lastname203...
# firstname203 lastname203 successfully added! (Another student added)
# Checking system to add firstname204 lastname204...
# firstname204 lastname204 successfully added! (Another student added)
# Checking system to add firstname205 lastname205...
# firstname205 lastname205 successfully added! (Another student added)
# Checking system to add firstname206 lastname206...
# firstname206 lastname206 successfully added! (Another student added)
# Checking system to add firstname207 lastname207...
# firstname207 lastname207 successfully added! (Another student added)
# Checking system to add firstname208 lastname208...
# firstname208 lastname208 successfully added! (Another student added)
# Checking system to add firstname209 lastname209...
# firstname209 lastname209 successfully added! (Another student added)
# Checking system to add firstname210 lastname210...
# firstname210 lastname210 successfully added! (Another student added)
# Checking system to add firstname211 lastname211...
# firstname211 lastname211 successfully added! (Another student added)
# Checking system to add firstname212 lastname212...
# firstname212 lastname212 successfully added! (Another student added)
# Checking system to add firstname213 lastname213...
# firstname213 lastname213 successfully added! (Another student added)
# Checking system to add firstname214 lastname214...
# firstname214 lastname214 successfully added! (Another student added)
# Checking system to add firstname215 lastname215...
# firstname215 lastname215 successfully added! (Another student added)
# Checking system to add firstname216 lastname216...
# firstname216 lastname216 successfully added! (Another student added)
# Checking system to add firstname217 lastname217...
# firstname217 lastname217 successfully added! (Another student added)
# Checking system to add firstname218 lastname218...
# firstname218 lastname218 successfully added! (Another student added)
# Checking system to add firstname219 lastname219...
# firstname219 lastname219 successfully added! (Another student added)
# Checking system to add firstname220 lastname220...
# firstname220 lastname220 successfully added! (Another student added)
# Checking system to add firstname221 lastname221...
# firstname221 lastname221 successfully added! (Another student added)
# Checking system to add firstname222 lastname222...
# firstname222 lastname222 successfully added! (Another student added)
# Checking system to add firstname223 lastname223...
# firstname223 lastname223 successfully added! (Another student added)
# Checking system to add firstname224 lastname224...
# firstname224 lastname224 successfully added! (Another student added)
# Checking system to add firstname225 lastname225...
# firstname225 lastname225 successfully added! (Another student added)
# Checking system to add firstname226 lastname226...
# firstname226 lastname226 successfully added! (Another student added)
# Checking system to add firstname227 lastname227...
# firstname227 lastname227 successfully added! (Another student added)
# Checking system to add firstname228 lastname228...
# firstname228 lastname228 successfully added! (Another student added)
# Checking system to add firstname229 lastname229...
# firstname229 lastname229 successfully added! (Another student added)
# Checking system to add firstname230 lastname230...
# firstname230 lastname230 successfully added! (Another student added)
# Checking system to add firstname231 lastname231...
# firstname231 lastname231 successfully added! (Another student added)
# Checking system to add firstname232 lastname232...
# firstname232 lastname232 successfully added! (Another student added)
# Checking system to add firstname233 lastname233...
# firstname233 lastname233 successfully added! (Another student added)
# Checking system to add firstname234 lastname234...
# firstname234 lastname234 successfully added! (Another student added)
# Checking system to add firstname235 lastname235...
# firstname235 lastname235 successfully added! (Another student added)
# Checking system to add firstname236 lastname236...
# firstname236 lastname236 successfully added! (Another student added)
# Checking system to add firstname237 lastname237...
# firstname237 lastname237 successfully added! (Another student added)
# Checking system to add firstname238 lastname238...
# firstname238 lastname238 successfully added! (Another student added)
# Checking system to add firstname239 lastname239...
# firstname239 lastname239 successfully added! (Another student added)
# Checking system to add firstname240 lastname240...
# firstname240 lastname240 successfully added! (Another student added)
# Checking system to add firstname241 lastname241...
# firstname241 lastname241 successfully added! (Another student added)
# Checking system to add firstname242 lastname242...
# firstname242 lastname242 successfully added! (Another student added)
# Checking system to add firstname243 lastname243...
# firstname243 lastname243 successfully added! (Another student added)
# Checking system to add firstname244 lastname244...
# firstname244 lastname244 successfully added! (Another student added)
# Checking system to add firstname245 lastname245...
# firstname245 lastname245 successfully added! (Another student added)
# Checking system to add firstname246 lastname246...
# firstname246 lastname246 successfully added! (Another student added)
# Checking system to add firstname247 lastname247...
# firstname247 lastname247 successfully added! (Another student added)
# Checking system to add firstname248 lastname248...
# firstname248 lastname248 successfully added! (Another student added)
# Checking system to add firstname249 lastname249...
# firstname249 lastname249 successfully added! (Another student added)
# Checking system to add firstname250 lastname250...
# firstname250 lastname250 successfully added! (Another student added)
# Checking system to add firstname251 lastname251...
# firstname251 lastname251 successfully added! (Another student added)
# Checking system to add firstname252 lastname252...
# firstname252 lastname252 successfully added! (Another student added)
# Checking system to add firstname253 lastname253...
# firstname253 lastname253 successfully added! (Another student added)
# Checking system to add firstname254 lastname254...
# firstname254 lastname254 successfully added! (Another student added)
# Checking system to add firstname255 lastname255...
# firstname255 lastname255 successfully added! (Another student added)
# Checking system to add firstname256 lastname256...
# firstname256 lastname256 successfully added! (Another student added)
# Checking system to add firstname257 lastname257...
# firstname257 lastname257 successfully added! (Another student added)
# Checking system to add firstname258 lastname258...
# firstname258 lastname258 successfully added! (Another student added)
# Checking system to add firstname259 lastname259...
# firstname259 lastname259 successfully added! (Another student added)
# Checking system to add firstname260 lastname260...
# firstname260 lastname260 successfully added! (Another student added)
# Checking system to add firstname261 lastname261...
# firstname261 lastname261 successfully added! (Another student added)
# Checking system to add firstname262 lastname262...
# firstname262 lastname262 successfully added! (Another student added)
# Checking system to add firstname263 lastname263...
# firstname263 lastname263 successfully added! (Another student added)
# Checking system to add firstname264 lastname264...
# firstname264 lastname264 successfully added! (Another student added)
# Checking system to add firstname265 lastname265...
# firstname265 lastname265 successfully added! (Another student added)
# Checking system to add firstname266 lastname266...
# firstname266 lastname266 successfully added! (Another student added)
# Checking system to add firstname267 lastname267...
# firstname267 lastname267 successfully added! (Another student added)
# Checking system to add firstname268 lastname268...
# firstname268 lastname268 successfully added! (Another student added)
# Checking system to add firstname269 lastname269...
# firstname269 lastname269 successfully added! (Another student added)
# Checking system to add firstname270 lastname270...
# firstname270 lastname270 successfully added! (Another student added)
# Checking system to add firstname271 lastname271...
# firstname271 lastname271 successfully added! (Another student added)
# Checking system to add firstname272 lastname272...
# firstname272 lastname272 successfully added! (Another student added)
# Checking system to add firstname273 lastname273...
# firstname273 lastname273 successfully added! (Another student added)
# Checking system to add firstname274 lastname274...
# firstname274 lastname274 successfully added! (Another student added)
# Checking system to add firstname275 lastname275...
# firstname275 lastname275 successfully added! (Another student added)
# Checking system to add firstname276 lastname276...
# firstname276 lastname276 successfully added! (Another student added)
# Checking system to add firstname277 lastname277...
# firstname277 lastname277 successfully added! (Another student added)
# Checking system to add firstname278 lastname278...
# firstname278 lastname278 successfully added! (Another student added)
# Checking system to add firstname279 lastname279...
# firstname279 lastname279 successfully added! (Another student added)
# Checking system to add firstname280 lastname280...
# firstname280 lastname280 successfully added! (Another student added)
# Checking system to add firstname281 lastname281...
# firstname281 lastname281 successfully added! (Another student added)
# Checking system to add firstname282 lastname282...
# firstname282 lastname282 successfully added! (Another student added)
# Checking system to add firstname283 lastname283...
# firstname283 lastname283 successfully added! (Another student added)
# Checking system to add firstname284 lastname284...
# firstname284 lastname284 successfully added! (Another student added)
# Checking system to add firstname285 lastname285...
# firstname285 lastname285 successfully added! (Another student added)
# Checking system to add firstname286 lastname286...
# firstname286 lastname286 successfully added! (Another student added)
# Checking system to add firstname287 lastname287...
# firstname287 lastname287 successfully added! (Another student added)
# Checking system to add firstname288 lastname288...
# firstname288 lastname288 successfully added! (Another student added)
# Checking system to add firstname289 lastname289...
# firstname289 lastname289 successfully added! (Another student added)
# Checking system to add firstname290 lastname290...
# firstname290 lastname290 successfully added! (Another student added)
# Checking system to add firstname291 lastname291...
# firstname291 lastname291 successfully added! (Another student added)
# Checking system to add firstname292 lastname292...
# firstname292 lastname292 successfully added! (Another student added)
# Checking system to add firstname293 lastname293...
# firstname293 lastname293 successfully added! (Another student added)
# Checking system to add firstname294 lastname294...
# firstname294 lastname294 successfully added! (Another student added)
# Checking system to add firstname295 lastname295...
# firstname295 lastname295 successfully added! (Another student added)
# Checking system to add firstname296 lastname296...
# firstname296 lastname296 successfully added! (Another student added)
# Checking system to add firstname297 lastname297...
# firstname297 lastname297 successfully added! (Another student added)
# Checking system to add firstname298 lastname298...
# firstname298 lastname298 successfully added! (Another student added)
# Checking system to add firstname299 lastname299...
# firstname299 lastname299 successfully added! (Another student added)
# Checking system to add firstname300 lastname300...
# firstname300 lastname300 successfully added! (Another student added)
# Checking system to add firstname301 lastname301...
# firstname301 lastname301 successfully added! (Another student added)
# Checking system to add firstname302 lastname302...
# firstname302 lastname302 successfully added! (Another student added)
# Checking system to add firstname303 lastname303...
# firstname303 lastname303 successfully added! (Another student added)
# Checking system to add firstname304 lastname304...
# firstname304 lastname304 successfully added! (Another student added)
# Checking system to add firstname305 lastname305...
# firstname305 lastname305 successfully added! (Another student added)
# Checking system to add firstname306 lastname306...
# firstname306 lastname306 successfully added! (Another student added)
# Checking system to add firstname307 lastname307...
# firstname307 lastname307 successfully added! (Another student added)
# Checking system to add firstname308 lastname308...
# firstname308 lastname308 successfully added! (Another student added)
# Checking system to add firstname309 lastname309...
# firstname309 lastname309 successfully added! (Another student added)
# Checking system to add firstname310 lastname310...
# firstname310 lastname310 successfully added! (Another student added)
# Checking system to add firstname311 lastname311...
# firstname311 lastname311 successfully added! (Another student added)
# Checking system to add firstname312 lastname312...
# firstname312 lastname312 successfully added! (Another student added)
# Checking system to add firstname313 lastname313...
# firstname313 lastname313 successfully added! (Another student added)
# Checking system to add firstname314 lastname314...
# firstname314 lastname314 successfully added! (Another student added)
# Checking system to add firstname315 lastname315...
# firstname315 lastname315 successfully added! (Another student added)
# Checking system to add firstname316 lastname316...
# firstname316 lastname316 successfully added! (Another student added)
# Checking system to add firstname317 lastname317...
# firstname317 lastname317 successfully added! (Another student added)
# Checking system to add firstname318 lastname318...
# firstname318 lastname318 successfully added! (Another student added)
# Checking system to add firstname319 lastname319...
# firstname319 lastname319 successfully added! (Another student added)
# Checking system to add firstname320 lastname320...
# firstname320 lastname320 successfully added! (Another student added)
# Checking system to add firstname321 lastname321...
# firstname321 lastname321 successfully added! (Another student added)
# Checking system to add firstname322 lastname322...
# firstname322 lastname322 successfully added! (Another student added)
# Checking system to add firstname323 lastname323...
# firstname323 lastname323 successfully added! (Another student added)
# Checking system to add firstname324 lastname324...
# firstname324 lastname324 successfully added! (Another student added)
# Checking system to add firstname325 lastname325...
# firstname325 lastname325 successfully added! (Another student added)
# Checking system to add firstname326 lastname326...
# firstname326 lastname326 successfully added! (Another student added)
# Checking system to add firstname327 lastname327...
# firstname327 lastname327 successfully added! (Another student added)
# Checking system to add firstname328 lastname328...
# firstname328 lastname328 successfully added! (Another student added)
# Checking system to add firstname329 lastname329...
# firstname329 lastname329 successfully added! (Another student added)
# Checking system to add firstname330 lastname330...
# firstname330 lastname330 successfully added! (Another student added)
# Checking system to add firstname331 lastname331...
# firstname331 lastname331 successfully added! (Another student added)
# Checking system to add firstname332 lastname332...
# firstname332 lastname332 successfully added! (Another student added)
# Checking system to add firstname333 lastname333...
# firstname333 lastname333 successfully added! (Another student added)
# Checking system to add firstname334 lastname334...
# firstname334 lastname334 successfully added! (Another student added)
# Checking system to add firstname335 lastname335...
# firstname335 lastname335 successfully added! (Another student added)
# Checking system to add firstname336 lastname336...
# firstname336 lastname336 successfully added! (Another student added)
# Checking system to add firstname337 lastname337...
# firstname337 lastname337 successfully added! (Another student added)
# Checking system to add firstname338 lastname338...
# firstname338 lastname338 successfully added! (Another student added)
# Checking system to add firstname339 lastname339...
# firstname339 lastname339 successfully added! (Another student added)
# Checking system to add firstname340 lastname340...
# firstname340 lastname340 successfully added! (Another student added)
# Checking system to add firstname341 lastname341...
# firstname341 lastname341 successfully added! (Another student added)
# Checking system to add firstname342 lastname342...
# firstname342 lastname342 successfully added! (Another student added)
# Checking system to add firstname343 lastname343...
# firstname343 lastname343 successfully added! (Another student added)
# Checking system to add firstname344 lastname344...
# firstname344 lastname344 successfully added! (Another student added)
# Checking system to add firstname345 lastname345...
# firstname345 lastname345 successfully added! (Another student added)
# Checking system to add firstname346 lastname346...
# firstname346 lastname346 successfully added! (Another student added)
# Checking system to add firstname347 lastname347...
# firstname347 lastname347 successfully added! (Another student added)
# Checking system to add firstname348 lastname348...
# firstname348 lastname348 successfully added! (Another student added)
# Checking system to add firstname349 lastname349...
# firstname349 lastname349 successfully added! (Another student added)
# Checking system to add firstname350 lastname350...
# firstname350 lastname350 successfully added! (Another student added)
# Checking system to add firstname351 lastname351...
# firstname351 lastname351 successfully added! (Another student added)
# Checking system to add firstname352 lastname352...
# firstname352 lastname352 successfully added! (Another student added)
# Checking system to add firstname353 lastname353...
# firstname353 lastname353 successfully added! (Another student added)
# Checking system to add firstname354 lastname354...
# firstname354 lastname354 successfully added! (Another student added)
# Checking system to add firstname355 lastname355...
# firstname355 lastname355 successfully added! (Another student added)
# Checking system to add firstname356 lastname356...
# firstname356 lastname356 successfully added! (Another student added)
# Checking system to add firstname357 lastname357...
# firstname357 lastname357 successfully added! (Another student added)
# Checking system to add firstname358 lastname358...
# firstname358 lastname358 successfully added! (Another student added)
# Checking system to add firstname359 lastname359...
# firstname359 lastname359 successfully added! (Another student added)
# Checking system to add firstname360 lastname360...
# firstname360 lastname360 successfully added! (Another student added)
# Checking system to add firstname361 lastname361...
# firstname361 lastname361 successfully added! (Another student added)
# Checking system to add firstname362 lastname362...
# firstname362 lastname362 successfully added! (Another student added)
# Checking system to add firstname363 lastname363...
# firstname363 lastname363 successfully added! (Another student added)
# Checking system to add firstname364 lastname364...
# firstname364 lastname364 successfully added! (Another student added)
# Checking system to add firstname365 lastname365...
# firstname365 lastname365 successfully added! (Another student added)
# Checking system to add firstname366 lastname366...
# firstname366 lastname366 successfully added! (Another student added)
# Checking system to add firstname367 lastname367...
# firstname367 lastname367 successfully added! (Another student added)
# Checking system to add firstname368 lastname368...
# firstname368 lastname368 successfully added! (Another student added)
# Checking system to add firstname369 lastname369...
# firstname369 lastname369 successfully added! (Another student added)
# Checking system to add firstname370 lastname370...
# firstname370 lastname370 successfully added! (Another student added)
# Checking system to add firstname371 lastname371...
# firstname371 lastname371 successfully added! (Another student added)
# Checking system to add firstname372 lastname372...
# firstname372 lastname372 successfully added! (Another student added)
# Checking system to add firstname373 lastname373...
# firstname373 lastname373 successfully added! (Another student added)
# Checking system to add firstname374 lastname374...
# firstname374 lastname374 successfully added! (Another student added)
# Checking system to add firstname375 lastname375...
# firstname375 lastname375 successfully added! (Another student added)
# Checking system to add firstname376 lastname376...
# firstname376 lastname376 successfully added! (Another student added)
# Checking system to add firstname377 lastname377...
# firstname377 lastname377 successfully added! (Another student added)
# Checking system to add firstname378 lastname378...
# firstname378 lastname378 successfully added! (Another student added)
# Checking system to add firstname379 lastname379...
# firstname379 lastname379 successfully added! (Another student added)
# Checking system to add firstname380 lastname380...
# firstname380 lastname380 successfully added! (Another student added)
# Checking system to add firstname381 lastname381...
# firstname381 lastname381 successfully added! (Another student added)
# Checking system to add firstname382 lastname382...
# firstname382 lastname382 successfully added! (Another student added)
# Checking system to add firstname383 lastname383...
# firstname383 lastname383 successfully added! (Another student added)
# Checking system to add firstname384 lastname384...
# firstname384 lastname384 successfully added! (Another student added)
# Checking system to add firstname385 lastname385...
# firstname385 lastname385 successfully added! (Another student added)
# Checking system to add firstname386 lastname386...
# firstname386 lastname386 successfully added! (Another student added)
# Checking system to add firstname387 lastname387...
# firstname387 lastname387 successfully added! (Another student added)
# Checking system to add firstname388 lastname388...
# firstname388 lastname388 successfully added! (Another student added)
# Checking system to add firstname389 lastname389...
# firstname389 lastname389 successfully added! (Another student added)
# Checking system to add firstname390 lastname390...
# firstname390 lastname390 successfully added! (Another student added)
# Checking system to add firstname391 lastname391...
# firstname391 lastname391 successfully added! (Another student added)
# Checking system to add firstname392 lastname392...
# firstname392 lastname392 successfully added! (Another student added)
# Checking system to add firstname393 lastname393...
# firstname393 lastname393 successfully added! (Another student added)
# Checking system to add firstname394 lastname394...
# firstname394 lastname394 successfully added! (Another student added)
# Checking system to add firstname395 lastname395...
# firstname395 lastname395 successfully added! (Another student added)
# Checking system to add firstname396 lastname396...
# firstname396 lastname396 successfully added! (Another student added)
# Checking system to add firstname397 lastname397...
# firstname397 lastname397 successfully added! (Another student added)
# Checking system to add firstname398 lastname398...
# firstname398 lastname398 successfully added! (Another student added)
# Checking system to add firstname399 lastname399...
# firstname399 lastname399 successfully added! (Another student added)
# Checking system to add firstname400 lastname400...
# firstname400 lastname400 successfully added! (Another student added)
# Checking system to add firstname401 lastname401...
# firstname401 lastname401 successfully added! (Another student added)
# Checking system to add firstname402 lastname402...
# firstname402 lastname402 successfully added! (Another student added)
# Checking system to add firstname403 lastname403...
# ...
# Deleting lastname944@myschool.edu...
#
# lastname944@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname945@myschool.edu...
# Deleting lastname945@myschool.edu...
#
# lastname945@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname946@myschool.edu...
# Deleting lastname946@myschool.edu...
#
# lastname946@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname947@myschool.edu...
# Deleting lastname947@myschool.edu...
#
# lastname947@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname948@myschool.edu...
# Deleting lastname948@myschool.edu...
#
# lastname948@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname949@myschool.edu...
# Deleting lastname949@myschool.edu...
#
# lastname949@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname950@myschool.edu...
# Deleting lastname950@myschool.edu...
#
# lastname950@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname951@myschool.edu...
# Deleting lastname951@myschool.edu...
#
# lastname951@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname952@myschool.edu...
# Deleting lastname952@myschool.edu...
#
# lastname952@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname953@myschool.edu...
# Deleting lastname953@myschool.edu...
#
# lastname953@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname954@myschool.edu...
# Deleting lastname954@myschool.edu...
#
# lastname954@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname955@myschool.edu...
# Deleting lastname955@myschool.edu...
#
# lastname955@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname956@myschool.edu...
# Deleting lastname956@myschool.edu...
#
# lastname956@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname957@myschool.edu...
# Deleting lastname957@myschool.edu...
#
# lastname957@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname958@myschool.edu...
# Deleting lastname958@myschool.edu...
#
# lastname958@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname959@myschool.edu...
# Deleting lastname959@myschool.edu...
#
# lastname959@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname960@myschool.edu...
# Deleting lastname960@myschool.edu...
#
# lastname960@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname961@myschool.edu...
# Deleting lastname961@myschool.edu...
#
# lastname961@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname962@myschool.edu...
# Deleting lastname962@myschool.edu...
#
# lastname962@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname963@myschool.edu...
# Deleting lastname963@myschool.edu...
#
# lastname963@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname964@myschool.edu...
# Deleting lastname964@myschool.edu...
#
# lastname964@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname965@myschool.edu...
# Deleting lastname965@myschool.edu...
#
# lastname965@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname966@myschool.edu...
# Deleting lastname966@myschool.edu...
#
# lastname966@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname967@myschool.edu...
# Deleting lastname967@myschool.edu...
#
# lastname967@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname968@myschool.edu...
# Deleting lastname968@myschool.edu...
#
# lastname968@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname969@myschool.edu...
# Deleting lastname969@myschool.edu...
#
# lastname969@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname970@myschool.edu...
# Deleting lastname970@myschool.edu...
#
# lastname970@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname971@myschool.edu...
# Deleting lastname971@myschool.edu...
#
# lastname971@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname972@myschool.edu...
# Deleting lastname972@myschool.edu...
#
# lastname972@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname973@myschool.edu...
# Deleting lastname973@myschool.edu...
#
# lastname973@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname974@myschool.edu...
# Deleting lastname974@myschool.edu...
#
# lastname974@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname975@myschool.edu...
# Deleting lastname975@myschool.edu...
#
# lastname975@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname976@myschool.edu...
# Deleting lastname976@myschool.edu...
#
# lastname976@myschool.edu successfully deleted!
# ......
# ----------------------------------------------------------------------
# Ran 8 tests in 40.955s
#
# OK
# Checking system to delete student associated with email lastname977@myschool.edu...
# Deleting lastname977@myschool.edu...
#
# lastname977@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname978@myschool.edu...
# Deleting lastname978@myschool.edu...
#
# lastname978@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname979@myschool.edu...
# Deleting lastname979@myschool.edu...
#
# lastname979@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname980@myschool.edu...
# Deleting lastname980@myschool.edu...
#
# lastname980@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname981@myschool.edu...
# Deleting lastname981@myschool.edu...
#
# lastname981@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname982@myschool.edu...
# Deleting lastname982@myschool.edu...
#
# lastname982@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname983@myschool.edu...
# Deleting lastname983@myschool.edu...
#
# lastname983@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname984@myschool.edu...
# Deleting lastname984@myschool.edu...
#
# lastname984@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname985@myschool.edu...
# Deleting lastname985@myschool.edu...
#
# lastname985@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname986@myschool.edu...
# Deleting lastname986@myschool.edu...
#
# lastname986@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname987@myschool.edu...
# Deleting lastname987@myschool.edu...
#
# lastname987@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname988@myschool.edu...
# Deleting lastname988@myschool.edu...
#
# lastname988@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname989@myschool.edu...
# Deleting lastname989@myschool.edu...
#
# lastname989@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname990@myschool.edu...
# Deleting lastname990@myschool.edu...
#
# lastname990@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname991@myschool.edu...
# Deleting lastname991@myschool.edu...
#
# lastname991@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname992@myschool.edu...
# Deleting lastname992@myschool.edu...
#
# lastname992@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname993@myschool.edu...
# Deleting lastname993@myschool.edu...
#
# lastname993@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname994@myschool.edu...
# Deleting lastname994@myschool.edu...
#
# lastname994@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname995@myschool.edu...
# Deleting lastname995@myschool.edu...
#
# lastname995@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname996@myschool.edu...
# Deleting lastname996@myschool.edu...
#
# lastname996@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname997@myschool.edu...
# Deleting lastname997@myschool.edu...
#
# lastname997@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname998@myschool.edu...
# Deleting lastname998@myschool.edu...
#
# lastname998@myschool.edu successfully deleted!
# Checking system to delete student associated with email lastname999@myschool.edu...
# Deleting lastname999@myschool.edu...
#
# lastname999@myschool.edu successfully deleted!
# 1000 students were deleted!
# Student loaded from file successfully
# Searching for students...
# Amount of time it took to find Samantha Mae: 0.0003304481506347656 seconds
# Amount of time it took to find Jane Smith: 0.0001277923583984375 seconds
#
#                   anderson@myschool.edu
#                   Anderson, Benjamin
#                   Enrolled in: DATA201
#                   Current grade for DATA201: C
#                   Mark: 75
#
#
#                   brown@myschool.edu
#                   Brown, Michael
#                   Enrolled in: DATA204
#                   Current grade for DATA204: B
#                   Mark: 85
#
#
#                   davis@myschool.edu
#                   Davis, Sarah
#                   Enrolled in: DATA203
#                   Current grade for DATA203: A
#                   Mark: 97
#
#
#                   doe@myschool.edu
#                   Doe, John
#                   Enrolled in: DATA201
#                   Current grade for DATA201: A-
#                   Mark: 93
#
#
#                   johnson@myschool.edu
#                   Johnson, Jack
#                   Enrolled in: DATA200
#                   Current grade for DATA200: D+
#                   Mark: 68
#
#
#                   jones@myschool.edu
#                   Jones, Emily
#                   Enrolled in: DATA203
#                   Current grade for DATA203: A-
#                   Mark: 92
#
#
#                   mae@myschool.edu
#                   Mae, Samantha
#                   Enrolled in: DATA200
#                   Current grade for DATA200: B-
#                   Mark: 80
#
#
#                   miller@myschool.edu
#                   Miller, William
#                   Enrolled in: DATA201
#                   Current grade for DATA201: C-
#                   Mark: 72
#
#
#                   moore@myschool.edu
#                   Moore, Charles
#                   Enrolled in: DATA200
#                   Current grade for DATA200: A
#                   Mark: 94
#
#
#                   russell@myschool.edu
#                   Russell, Sally
#                   Enrolled in: DATA200
#                   Current grade for DATA200: A-
#                   Mark: 90
#
#
#                   smith@myschool.edu
#                   Smith, Jane
#                   Enrolled in: DATA202
#                   Current grade for DATA202: B+
#                   Mark: 88
#
#
#                   taylor@myschool.edu
#                   Taylor, Olivia
#                   Enrolled in: DATA204
#                   Current grade for DATA204: B+
#                   Mark: 89
#
#
#                   wilson@myschool.edu
#                   Wilson, Lucy
#                   Enrolled in: DATA202
#                   Current grade for DATA202: B-
#                   Mark: 80
#
# Amount of time it took to sort in ascending order: 0.000217437744140625 seconds
#
#                   wilson@myschool.edu
#                   Wilson, Lucy
#                   Enrolled in: DATA202
#                   Current grade for DATA202: B-
#                   Mark: 80
#
#
#                   taylor@myschool.edu
#                   Taylor, Olivia
#                   Enrolled in: DATA204
#                   Current grade for DATA204: B+
#                   Mark: 89
#
#
#                   smith@myschool.edu
#                   Smith, Jane
#                   Enrolled in: DATA202
#                   Current grade for DATA202: B+
#                   Mark: 88
#
#
#                   russell@myschool.edu
#                   Russell, Sally
#                   Enrolled in: DATA200
#                   Current grade for DATA200: A-
#                   Mark: 90
#
#
#                   moore@myschool.edu
#                   Moore, Charles
#                   Enrolled in: DATA200
#                   Current grade for DATA200: A
#                   Mark: 94
#
#
#                   miller@myschool.edu
#                   Miller, William
#                   Enrolled in: DATA201
#                   Current grade for DATA201: C-
#                   Mark: 72
#
#
#                   mae@myschool.edu
#                   Mae, Samantha
#                   Enrolled in: DATA200
#                   Current grade for DATA200: B-
#                   Mark: 80
#
#
#                   jones@myschool.edu
#                   Jones, Emily
#                   Enrolled in: DATA203
#                   Current grade for DATA203: A-
#                   Mark: 92
#
#
#                   johnson@myschool.edu
#                   Johnson, Jack
#                   Enrolled in: DATA200
#                   Current grade for DATA200: D+
#                   Mark: 68
#
#
#                   doe@myschool.edu
#                   Doe, John
#                   Enrolled in: DATA201
#                   Current grade for DATA201: A-
#                   Mark: 93
#
#
#                   davis@myschool.edu
#                   Davis, Sarah
#                   Enrolled in: DATA203
#                   Current grade for DATA203: A
#                   Mark: 97
#
#
#                   brown@myschool.edu
#                   Brown, Michael
#                   Enrolled in: DATA204
#                   Current grade for DATA204: B
#                   Mark: 85
#
#
#                   anderson@myschool.edu
#                   Anderson, Benjamin
#                   Enrolled in: DATA201
#                   Current grade for DATA201: C
#                   Mark: 75
#
# Amount of time it took to sort in ascending order: 0.0001800060272216797 seconds
# Checking system to add DATA1000...
# DATA1000 successfully added! (Another course added)
# Course added successfully!
# Checking system to delete course associated with the course id DATA1000...
# Deleting DATA1000...
#
# DATA1000 successfully deleted!
# Course deleted successfully!
# Checking system to add Test Professor...
# Test Professor successfully added! (Another professor added)
# Professor added successfully!
# The rank for Test Professor has been updated to Tenured Lecturer
# Professor updated successfully!
# Checking system to delete professor associated with the email professor@myschool.edu...
# Deleting professor@myschool.edu...
#
# professor@myschool.edu successfully deleted!
# Professor deleted successfully!
